# %%
import numpy as np
import matplotlib.pyplot as plt
import time
import ctypes as c
from subprocess import Popen, PIPE
import threading
import tempfile
import multiprocessing
import os

def Bolsig(Y,X):
    sigma_m=Y[0]*1e-20
    E_th=Y[1]
    slope=Y[2]*1e-20
    
    t=time.time()
    with tempfile.TemporaryDirectory() as tmpdirname:  
        print('Created temporary directory:', tmpdirname)
        
        os.popen('cp bolsigminus '+tmpdirname)
        os.chdir(tmpdirname)
        
        #Creating LXCat0.txt
        f=open("LXCat0.txt","w")
        n=500
        E=np.logspace(-3,1,n)

        f.write('----------------------\n')
        f.write('ELASTIC\nReid\n')
        f.write('1.371541e-4 / mass ratio\n')
        f.write('----------------------\n')
    
        for i in range(n):
            f.write(str(E[i])+' '+str(sigma_m)+'\n')

        f.write('----------------------\n')
        f.write('EXCITATION\nReid\n')
        f.write(str(E_th)+' / Thresold Energy\n')
        f.write('1.371541e-4 / mass ratio\n')
        f.write('----------------------\n')
        sigma_exc=slope*(E-E_th)*np.heaviside(E-E_th,1)
        for i in range(n):
            f.write(str(E[i])+' '+str(sigma_exc[i])+'\n')
        f.close()
        
        
        
        
        #Creating ex.dat
        f=open(tmpdirname+"/ex.dat","w")
        f.write("READCOLLISIONS\n")
        f.write("LXCat0.txt\nReid\n1\n")
        f.write("CONDITIONS\n")
        f.write("1       / Electric field / N (Td)\n")
        f.write("0        / Angular field frequency / N (m3/s)\n")
        f.write("0.        / Cosine of E-B field angle\n")
        f.write("0.       / Gas temperature (K)\n")
        f.write("300.      / Excitation temperature (K)\n")
        f.write("0.        / Transition energy (eV)\n")
        f.write("0.        / Ionization degree\n")
        f.write("1e-6      / Plasma density (1/m3)\n")
        f.write("1.        / Ion charge parameter\n")
        f.write("1.        / Ion/neutral mass ratio\n")
        f.write("1         / e-e momentum effects: 0=No; 1=Yes*\n")
        f.write("1         / Energy sharing: 1=Equal*; 2=One takes all\n")
        f.write("1         / Growth: 1=Temporal*; 2=Spatial; 3=Not included; 4=Grad-n expansion\n")
        f.write("0.        / Maxwellian mean energy (eV) \n")
        f.write("100       / # of grid points\n")
        f.write("0         / Manual grid: 0=No; 1=Linear; 2=Parabolic \n")
        f.write("1000.      / Manual maximum energy (eV)\n")
        f.write("1e-10     / Precision\n")
        f.write("1e-5      / Convergence\n")
        f.write("1000      / Maximum # of iterations\n")
        f.write("1        / Gas composition fractions\n")
        f.write("1         / Normalize composition to unity: 0=No; 1=Yes\n")
        f.write("RUNSERIES\n")
        f.write("1          / Variable: 1=E/N; 2=Mean energy; 3=Maxwellian energy \n")
        f.write("0.001 1000.  / Min Max\n")
        f.write("1000         / Number \n")
        f.write("3          / Type: 1=Linear; 2=Quadratic; 3=Exponential\n")
        f.write("SAVERESULTS\n")
        f.write("Reid.dat        / File \n")
        f.write("3        / Format: 1=Run by run; 2=Combined; 3=E/N; 4=Energy; 5=SIGLO; 6=PLASIMO\n")
        f.write("1        / Conditions: 0=No; 1=Yes\n")
        f.write("1        / Transport coefficients: 0=No; 1=Yes\n")
        f.write("1        / Rate coefficients: 0=No; 1=Yes\n")
        f.write("0        / Reverse rate coefficients: 0=No; 1=Yes\n")
        f.write("0        / Energy loss coefficients: 0=No; 1=Yes\n")
        f.write("1        / Distribution function: 0=No; 1=Yes \n")
        f.write("0        / Skip failed runs: 0=No; 1=Yes\n")
        f.write("END")
        f.close()
        

        
        
        
        #Executing Bolsig
        process = Popen(['./bolsigminus', 'ex.dat'], stdout=PIPE, stderr=PIPE)
        stdout, stderr = process.communicate()
        #print(stdout)
        
  
        
        
        
        #Reading from Reid.dat
        f=open("Reid.dat","r")
        n=512
    
        E=np.zeros(n)
        out=np.zeros((n,3))
        for line in f:
            if line[:8]=='E/N (Td)' and line[8:].strip()=='Mean energy (eV)':
                for i in range(n):
                    l=f.readline().strip()
                    if len(l)==0: break
                    E[i], out[i,0] = [float(x) for x in l.split()]
            if line[:8]=='E/N (Td)' and line[8:].strip()=='Mobility *N (1/m/V/s)':
                for i in range(n):
                    l=f.readline().strip()
                    if len(l)==0: break
                    E[i], out[i,1] = [float(x) for x in l.split()]
            if line[:8]=='E/N (Td)' and line[8:].strip()=='Diffusion coefficient *N (1/m/s)':
                for i in range(n):
                    l=f.readline().strip()
                    if len(l)==0: break
                    E[i], out[i,2] = [float(x) for x in l.split()]

        out[:,1]=out[:,1]*E*1e-21 #Drift Velocity
        out[:,2]=out[:,2]*1e-24 #Diffusion coefficient
        
        X.put(np.log10(out))
        print("yo",X.empty())
        
    print('time:',time.time()-t,Y)    
    #return out#np.log10(out)
        
t = time.time()

n=8
sigma_m=10**(np.random.rand(n)) #in (1 to 10) (Angstrom)^2
E_th=10**(np.random.rand(n)-1)  #in (0.1 to 1) eV 
slope=10**(np.random.rand(n)*2) #in (1 to 100) (Angstrom)^2
Y=np.zeros((n,3))
Y[:,0]=sigma_m
Y[:,1]=E_th
Y[:,2]=slope

X = multiprocessing.Queue()

p=[]
for i in range(n):
    p.append(multiprocessing.Process(target=Bolsig, args=(Y[i,:],X)))
    p[i].start()
    
for i in range(n):
    p[i].join()
    

cross=open('Y_train.csv','wb')
trans=open('X_train.csv','wb')
np.savetxt(cross,Y,delimiter=',')
print("lo",X.empty())
while not X.empty():
    temp=X.get()
    plt.plot(temp[:,0])
    plt.show()
    np.savetxt(trans,np.reshape(temp,(1,-1)),delimiter=',')

cross.close()
trans.close()
print("done in : ",time.time()-t)
# Out:
# Created temporary directory: /tmp/tmp9pxa822l
# Created temporary directory: /tmp/tmpes6aw0ga
# Created temporary directory: /tmp/tmpzywbdmy5
# Created temporary directory: /tmp/tmp2rmocb1z
# Created temporary directory: /tmp/tmpxzweh9uw
# Created temporary directory: /tmp/tmpzaxdk5vd
# Created temporary directory: /tmp/tmpqwwtvuw6
# Process Process-407:
# Created temporary directory: /tmp/tmplk2igcd4
# Traceback (most recent call last):
#   File "/home/vinit/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/vinit/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-179-8eb71eb396e6>", line 99, in Bolsig
#     process = Popen(['./bolsigminus', 'ex.dat'], stdout=PIPE, stderr=PIPE)
#   File "/home/vinit/anaconda3/envs/tensorflow/lib/python3.6/subprocess.py", line 729, in __init__
#     restore_signals, start_new_session)
#   File "/home/vinit/anaconda3/envs/tensorflow/lib/python3.6/subprocess.py", line 1364, in _execute_child
#     raise child_exception_type(errno_num, err_msg, err_filename)
# FileNotFoundError: [Errno 2] No such file or directory: './bolsigminus': './bolsigminus'
# yo True
# time: 3.6685116291046143 [ 7.33074239  0.10665358 15.80845731]
# yo False
# time: 3.9979641437530518 [1.6731795  0.89107243 7.22415866]
# yo False
# time: 4.038243293762207 [ 5.65389915  0.85243324 34.1295144 ]
# yo False
# time: 5.418630599975586 [ 1.89372952  0.14048164 32.95641329]
# yo False
# time: 7.76031231880188 [9.70151091 0.77238771 3.69227301]
# yo False
# time: 11.82198166847229 [1.60254855 0.87438735 1.08105542]
# yo False
# time: 14.488334894180298 [2.36513337 0.11533872 2.28377855]
# Process Process-409:
# Process Process-408:
# Process Process-410:
# Traceback (most recent call last):
# Traceback (most recent call last):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-179-8eb71eb396e6> in <module>
#     156
#     157 for i in range(n):
# --> 158     p[i].join()
#     159
#     160
#
# ~/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/process.py in join(self, timeout)
#     122         assert self._parent_pid == os.getpid(), 'can only join a child process'
#     123         assert self._popen is not None, 'can only join a started process'
# --> 124         res = self._popen.wait(timeout)
#     125         if res is not None:
#     126             _children.discard(self)
#
# ~/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/popen_fork.py in wait(self, timeout)
#      48                     return None
#      49             # This shouldn't block if wait() returned successfully.
# ---> 50             return self.poll(os.WNOHANG if timeout == 0.0 else 0)
#      51         return self.returncode
#      52
#
# ~/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/popen_fork.py in poll(self, flag)
#      26             while True:
#      27                 try:
# ---> 28                     pid, sts = os.waitpid(self.pid, flag)
#      29                 except OSError as e:
#      30                     # Child process not yet created. See #1731717
#
# KeyboardInterrupt:
# Traceback (most recent call last):
#   File "/home/vinit/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/process.py", line 261, in _bootstrap
#     util._exit_function()
#   File "/home/vinit/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/process.py", line 261, in _bootstrap
#     util._exit_function()
#   File "/home/vinit/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/process.py", line 261, in _bootstrap
#     util._exit_function()
#   File "/home/vinit/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/util.py", line 322, in _exit_function
#     _run_finalizers()
#   File "/home/vinit/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/util.py", line 322, in _exit_function
#     _run_finalizers()
#   File "/home/vinit/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/util.py", line 322, in _exit_function
#     _run_finalizers()
#   File "/home/vinit/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/util.py", line 262, in _run_finalizers
#     finalizer()
#   File "/home/vinit/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/util.py", line 262, in _run_finalizers
#     finalizer()
#   File "/home/vinit/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/util.py", line 262, in _run_finalizers
#     finalizer()
#   File "/home/vinit/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/util.py", line 186, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/home/vinit/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/util.py", line 186, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/home/vinit/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/queues.py", line 191, in _finalize_join
#     thread.join()
#   File "/home/vinit/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/queues.py", line 191, in _finalize_join
#     thread.join()
#   File "/home/vinit/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/util.py", line 186, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/home/vinit/anaconda3/envs/tensorflow/lib/python3.6/threading.py", line 1056, in join
#     self._wait_for_tstate_lock()
#   File "/home/vinit/anaconda3/envs/tensorflow/lib/python3.6/multiprocessing/queues.py", line 191, in _finalize_join
#     thread.join()
#   File "/home/vinit/anaconda3/envs/tensorflow/lib/python3.6/threading.py", line 1056, in join
#     self._wait_for_tstate_lock()
#   File "/home/vinit/anaconda3/envs/tensorflow/lib/python3.6/threading.py", line 1072, in _wait_for_tstate_lock
#     elif lock.acquire(block, timeout):
#   File "/home/vinit/anaconda3/envs/tensorflow/lib/python3.6/threading.py", line 1056, in join
#     self._wait_for_tstate_lock()
#   File "/home/vinit/anaconda3/envs/tensorflow/lib/python3.6/threading.py", line 1072, in _wait_for_tstate_lock
#     elif lock.acquire(block, timeout):
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/vinit/anaconda3/envs/tensorflow/lib/python3.6/threading.py", line 1072, in _wait_for_tstate_lock
#     elif lock.acquire(block, timeout):
# KeyboardInterrupt
