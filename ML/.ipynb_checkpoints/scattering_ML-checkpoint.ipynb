# %%
import numpy as np # linear algebra
import matplotlib.pyplot as plt
import time
# %matplotlib inline
import tensorflow
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv1D, MaxPool1D, BatchNormalization
from keras.layers.advanced_activations import LeakyReLU, PReLU
from keras.optimizers import Adam
from keras.callbacks import LearningRateScheduler

# %%
x_train=np.loadtxt('X_train.csv',delimiter=',')
y_train=np.loadtxt('Y_train.csv',delimiter=',')
x_test=np.loadtxt('X_test.csv',delimiter=',')
y_test=np.loadtxt('Y_test.csv',delimiter=',')

plt.plot(x_train[3,:])
plt.show()

mean=np.mean(x_train,axis=0)
std=np.std(x_train,axis=0)
x_train=(x_train-mean)/std
x_test=(x_test-mean)/std
x_train=np.expand_dims(x_train, axis=2)
x_test=np.expand_dims(x_test, axis=2)

'''y_train=np.log10(y_train)
y_test=np.log10(y_test)
y_train[:,1]=y_train[:,1]+1
y_test[:,1]=y_test[:,1]+1'''
max=np.max(y_train,axis=0)
y_train=y_train/max
y_test=y_test/max
plt.plot(y_train[])

print(np.shape(x_train),np.shape(y_train),np.shape(x_test),np.shape(y_test))
# Out:
# (1000, 128, 1) (1000, 3) (200, 128, 1) (200, 3)

# %%
#Data Analysis
X = x_train[:,:,0]
X=(X-np.mean(X,axis=0))/np.std(X,axis=0)
X_=np.matrix.transpose(X)

plt.plot(np.transpose(X))
plt.show()

lambd,W=np.linalg.eig(np.matmul(X_,X))

plt.plot(np.log(lambd))
plt.show()

Z=np.matmul(X,W[:,:3])
print(np.shape(Z))

sc=plt.scatter(Z[:,0],Z[:,1], c=y_train[:,0], cmap="coolwarm")
plt.colorbar()
plt.show()

sc=plt.scatter(Z[:,0],Z[:,1], c=y_train[:,1], cmap="coolwarm")
plt.colorbar()
plt.show()

sc=plt.scatter(Z[:,0],Z[:,1], c=y_train[:,2], cmap="coolwarm")
plt.colorbar()
plt.show()


for i in range(5):
    plt.plot(W[:,i])
plt.show()
# Out:
# (1000, 3)

# %%
model = Sequential()

model.add(Conv1D(filters = 16, kernel_size = 6, activation='relu', input_shape = (128,1)))
model.add(BatchNormalization())
#model.add(Conv1D(filters = 16, kernel_size = 3, activation='relu'))
#model.add(BatchNormalization())
#model.add(Conv1D(filters = 16, kernel_size = 3, activation='relu'))
#model.add(BatchNormalization())
model.add(MaxPool1D(strides=2))
model.add(Dropout(0.25))

model.add(Conv1D(filters = 32, kernel_size = 6, activation='relu'))
model.add(BatchNormalization())
#model.add(Conv1D(filters = 32, kernel_size = 3, activation='relu'))
#model.add(BatchNormalization())
#model.add(Conv1D(filters = 32, kernel_size = 3, activation='relu'))
#model.add(BatchNormalization())
model.add(MaxPool1D(strides=2))
model.add(Dropout(0.25))

model.add(Flatten())

model.add(Dense(1024, activation='linear'))
model.add(LeakyReLU(alpha=.1))
model.add(BatchNormalization())
model.add(Dropout(0.25))

model.add(Dense(512, activation='linear'))
model.add(LeakyReLU(alpha=.1))
model.add(BatchNormalization())
model.add(Dropout(0.25))

model.add(Dense(1024, activation='linear'))
model.add(LeakyReLU(alpha=.1))
model.add(BatchNormalization())
model.add(Dropout(0.25))

model.add(Dense(512, activation='linear'))
model.add(LeakyReLU(alpha=.1))
model.add(BatchNormalization())
model.add(Dropout(0.25))

model.add(Dense(1024, activation='linear'))
model.add(LeakyReLU(alpha=.1))
model.add(BatchNormalization())
model.add(Dropout(0.25))

model.add(Dense(512, activation='linear'))
model.add(LeakyReLU(alpha=.1))
model.add(BatchNormalization())
model.add(Dropout(0.25))

model.add(Dense(3, activation='sigmoid'))

model.compile(loss='mean_squared_error', optimizer = Adam(lr=1e-4), metrics=["accuracy"]) #binary_crossentropy

annealer = LearningRateScheduler(lambda x: 1e-3 * 0.9 ** x)

hist = model.fit(x=x_train, y=y_train, batch_size=512,
                           epochs=40, #Increase this when not on Kaggle kernel
                           verbose=2,  #1 for ETA, 0 for silent
                           validation_data=(x_test, y_test), #For speed
                           callbacks=[annealer])
# Out:
# Train on 1000 samples, validate on 200 samples
# Epoch 1/40
#  - 16s - loss: 0.1128 - acc: 0.4780 - val_loss: 0.0637 - val_acc: 0.7050
# Epoch 2/40
#  - 0s - loss: 0.0763 - acc: 0.6330 - val_loss: 0.0660 - val_acc: 0.7250
# Epoch 3/40
#  - 0s - loss: 0.0664 - acc: 0.6600 - val_loss: 0.0596 - val_acc: 0.7400
# Epoch 4/40
#  - 0s - loss: 0.0654 - acc: 0.6440 - val_loss: 0.0404 - val_acc: 0.7300
# Epoch 5/40
#  - 0s - loss: 0.0590 - acc: 0.6940 - val_loss: 0.0400 - val_acc: 0.7550
# Epoch 6/40
#  - 0s - loss: 0.0523 - acc: 0.6970 - val_loss: 0.0329 - val_acc: 0.7750
# Epoch 7/40
#  - 0s - loss: 0.0474 - acc: 0.6910 - val_loss: 0.0297 - val_acc: 0.7800
# Epoch 8/40
#  - 0s - loss: 0.0452 - acc: 0.7060 - val_loss: 0.0275 - val_acc: 0.7300
# Epoch 9/40
#  - 0s - loss: 0.0412 - acc: 0.7200 - val_loss: 0.0292 - val_acc: 0.7600
# Epoch 10/40
#  - 0s - loss: 0.0408 - acc: 0.7350 - val_loss: 0.0204 - val_acc: 0.7950
# Epoch 11/40
#  - 0s - loss: 0.0374 - acc: 0.7440 - val_loss: 0.0202 - val_acc: 0.8250
# Epoch 12/40
#  - 0s - loss: 0.0371 - acc: 0.7170 - val_loss: 0.0203 - val_acc: 0.8000
# Epoch 13/40
#  - 0s - loss: 0.0348 - acc: 0.7140 - val_loss: 0.0186 - val_acc: 0.8100
# Epoch 14/40
#  - 0s - loss: 0.0324 - acc: 0.7180 - val_loss: 0.0188 - val_acc: 0.8200
# Epoch 15/40
#  - 0s - loss: 0.0313 - acc: 0.7340 - val_loss: 0.0187 - val_acc: 0.8300
# Epoch 16/40
#  - 0s - loss: 0.0324 - acc: 0.7450 - val_loss: 0.0171 - val_acc: 0.8350
# Epoch 17/40
#  - 0s - loss: 0.0307 - acc: 0.7290 - val_loss: 0.0157 - val_acc: 0.8450
# Epoch 18/40
#  - 0s - loss: 0.0309 - acc: 0.7730 - val_loss: 0.0152 - val_acc: 0.8300
# Epoch 19/40
#  - 0s - loss: 0.0316 - acc: 0.7560 - val_loss: 0.0155 - val_acc: 0.8200
# Epoch 20/40
#  - 0s - loss: 0.0285 - acc: 0.7490 - val_loss: 0.0158 - val_acc: 0.8350
# Epoch 21/40
#  - 0s - loss: 0.0299 - acc: 0.7290 - val_loss: 0.0158 - val_acc: 0.8400
# Epoch 22/40
#  - 0s - loss: 0.0284 - acc: 0.7680 - val_loss: 0.0155 - val_acc: 0.8400
# Epoch 23/40
#  - 0s - loss: 0.0284 - acc: 0.7510 - val_loss: 0.0148 - val_acc: 0.8450
# Epoch 24/40
#  - 0s - loss: 0.0291 - acc: 0.7670 - val_loss: 0.0142 - val_acc: 0.8500
# Epoch 25/40
#  - 0s - loss: 0.0292 - acc: 0.7530 - val_loss: 0.0139 - val_acc: 0.8450
# Epoch 26/40
#  - 0s - loss: 0.0273 - acc: 0.7710 - val_loss: 0.0135 - val_acc: 0.8400
# Epoch 27/40
#  - 0s - loss: 0.0281 - acc: 0.7570 - val_loss: 0.0132 - val_acc: 0.8400
# Epoch 28/40
#  - 0s - loss: 0.0283 - acc: 0.7390 - val_loss: 0.0132 - val_acc: 0.8450
# Epoch 29/40
#  - 0s - loss: 0.0266 - acc: 0.7370 - val_loss: 0.0133 - val_acc: 0.8400
# Epoch 30/40
#  - 0s - loss: 0.0268 - acc: 0.7670 - val_loss: 0.0134 - val_acc: 0.8400
# Epoch 31/40
#  - 0s - loss: 0.0259 - acc: 0.7600 - val_loss: 0.0136 - val_acc: 0.8450
# Epoch 32/40
#  - 0s - loss: 0.0261 - acc: 0.7410 - val_loss: 0.0137 - val_acc: 0.8400
# Epoch 33/40
#  - 0s - loss: 0.0263 - acc: 0.7470 - val_loss: 0.0139 - val_acc: 0.8350
# Epoch 34/40
#  - 0s - loss: 0.0266 - acc: 0.7730 - val_loss: 0.0141 - val_acc: 0.8450
# Epoch 35/40
#  - 0s - loss: 0.0271 - acc: 0.7480 - val_loss: 0.0142 - val_acc: 0.8400
# Epoch 36/40
#  - 0s - loss: 0.0268 - acc: 0.7560 - val_loss: 0.0144 - val_acc: 0.8450
# Epoch 37/40
#  - 0s - loss: 0.0276 - acc: 0.7610 - val_loss: 0.0145 - val_acc: 0.8350
# Epoch 38/40
#  - 0s - loss: 0.0249 - acc: 0.7570 - val_loss: 0.0146 - val_acc: 0.8300
# Epoch 39/40
#  - 0s - loss: 0.0268 - acc: 0.7600 - val_loss: 0.0147 - val_acc: 0.8350
# Epoch 40/40
#  - 1s - loss: 0.0250 - acc: 0.7720 - val_loss: 0.0148 - val_acc: 0.8400

# %%
plt.plot(hist.history['acc'], color='b')
plt.plot(hist.history['val_acc'], color='r')
plt.show()

# %%
model.evaluate(x_test, y_test)
# Out:
# 200/200 [==============================] - 0s 394us/step
# [0.01482059471309185, 0.84]

# %%
for i in range(3):
    plt.scatter(model.predict(x_train)[:,i],y_train[:,i])
    plt.plot(np.arange(0,1,0.01),np.arange(0,1,0.01))
    plt.show()

# %%
for i in range(3):
    plt.scatter(model.predict(x_test)[:,i],y_test[:,i])
    plt.plot(np.arange(0,1,0.01),np.arange(0,1,0.01))
    plt.show()
