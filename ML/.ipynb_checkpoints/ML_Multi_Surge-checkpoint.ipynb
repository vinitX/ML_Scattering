# %%
import numpy as np # linear algebra
from scipy import signal
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import time
# %matplotlib inline
import tensorflow
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv1D, MaxPool1D, BatchNormalization
from keras.layers.advanced_activations import LeakyReLU, PReLU
from keras.optimizers import Adam
from keras.callbacks import LearningRateScheduler
from sklearn.model_selection import train_test_split
import keras.backend as K

# %%
t=time.time()
X=np.loadtxt('X.csv',delimiter=',')
Y=np.loadtxt('Y.csv',delimiter=',')
print(time.time()-t)
# Out:
# 0.29865217208862305

# %%
X=np.reshape(X,(-1,1000,4))

eps=1e-15

X=np.isnan(X)
#X=np.log10(X+eps)
'''
#Normalising X
for i in range(4):
    mean=np.mean(X[:,:,i])
    std=np.std(X[:,:,i])
    X[:,:,i]=(X[:,:,i]-mean)/std
'''

Y=np.log10(Y*1e20)

#Min_Max Scaling of Y
Y=Y-np.min(Y)
Y=Y/np.max(Y)
# Out:
# /home/vinit/anaconda3/envs/tensorflow/lib/python3.6/site-packages/ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in log10
#   after removing the cwd from sys.path.

# %%
plt.plot(np.transpose(X[:,:,0]))
plt.show()
plt.plot(np.transpose(X[:,:,1]))
plt.show()
plt.plot(np.transpose(X[:,:,2]))
plt.show()
plt.plot(np.transpose(X[:,:,3]))
plt.show()

plt.plot(np.transpose(Y[:10,:]))
#plt.plot((Y[idx,:]))

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)

print(np.shape(x_train),np.shape(y_train),np.shape(x_test),np.shape(y_test))
# Out:
# (80, 1000, 4) (80, 500) (20, 1000, 4) (20, 500)

# %%
#Data Analysis
'''print(np.shape(X))
X = np.reshape(np.transpose(X,(0,2,1)),(-1,1000*3))
X=(X-np.mean(X,axis=0))/np.std(X,axis=0)
X_=np.matrix.transpose(X)

lambd,W=np.linalg.eig(np.matmul(X_,X))

plt.plot(np.log(lambd))
plt.show()

Z=np.abs(np.matmul(X,W[:,:3]))
print(np.shape(Z))

for i in range(4):
    plt.scatter(Z[:,0],Z[:,1], c=Y[:,i], cmap="coolwarm")
    plt.show()
'''
# Out:
# 'print(np.shape(X))\nX = np.reshape(np.transpose(X,(0,2,1)),(-1,1000*3))\nX=(X-np.mean(X,axis=0))/np.std(X,axis=0)\nX_=np.matrix.transpose(X)\n\nlambd,W=np.linalg.eig(np.matmul(X_,X))\n\nplt.plot(np.log(lambd))\nplt.show()\n\nZ=np.abs(np.matmul(X,W[:,:3]))\nprint(np.shape(Z))\n\nfor i in range(4):\n    plt.scatter(Z[:,0],Z[:,1], c=Y[:,i], cmap="coolwarm")\n    plt.show()\n'

# %%
model = Sequential()

model.add(Flatten(input_shape=(1000,4)))
model.add(Dense(2048, activation='linear'))
model.add(LeakyReLU(alpha=.1))
model.add(BatchNormalization())
model.add(Dropout(0.25))

model.add(Dense(4046, activation='linear'))
model.add(LeakyReLU(alpha=.1))
model.add(BatchNormalization())
model.add(Dropout(0.25))

model.add(Dense(2048, activation='linear'))
model.add(LeakyReLU(alpha=.1))
model.add(BatchNormalization())
model.add(Dropout(0.25))

model.add(Dense(500, activation='sigmoid'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_5 (Flatten)          (None, 4000)              0
# _________________________________________________________________
# dense_17 (Dense)             (None, 2048)              8194048
# _________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)   (None, 2048)              0
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 2048)              8192
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 2048)              0
# _________________________________________________________________
# dense_18 (Dense)             (None, 4046)              8290254
# _________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)   (None, 4046)              0
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 4046)              16184
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 4046)              0
# _________________________________________________________________
# dense_19 (Dense)             (None, 2048)              8288256
# _________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)   (None, 2048)              0
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 2048)              8192
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 2048)              0
# _________________________________________________________________
# dense_20 (Dense)             (None, 500)               1024500
# =================================================================
# Total params: 25,829,626
# Trainable params: 25,813,342
# Non-trainable params: 16,284
# _________________________________________________________________

# %%
#import tensorflow as tf
def loss_func(y_true,y_pred):
    lambd = 0.01 #Regularisation parameter
    return K.sqrt(K.sum(K.square(y_pred - y_true), axis=-1)) #+ lambd*K.sum(K.square(y_pred[:,1:]-y_pred[:,:-1]))

# %%
model.compile(loss=loss_func, optimizer = Adam(lr=1e-4), metrics=["accuracy"]) #binary_crossentropy

annealer = LearningRateScheduler(lambda x: 1e-3 * 0.9 ** x)

hist = model.fit(x=x_train, y=y_train, batch_size=512,
                           epochs=20, #Increase this when not on Kaggle kernel
                           verbose=2,  #1 for ETA, 0 for silent
                           validation_data=(x_test, y_test), #For speed
                           callbacks=[annealer])
# Out:
# Train on 80 samples, validate on 20 samples
# Epoch 1/20
#  - 5s - loss: nan - acc: 0.1125 - val_loss: nan - val_acc: 0.1000
# Epoch 2/20
#  - 1s - loss: nan - acc: 0.1125 - val_loss: nan - val_acc: 0.1000
# Epoch 3/20
#  - 0s - loss: nan - acc: 0.1125 - val_loss: nan - val_acc: 0.1000
# Epoch 4/20
#  - 0s - loss: nan - acc: 0.1125 - val_loss: nan - val_acc: 0.1000
# Epoch 5/20
#  - 0s - loss: nan - acc: 0.1125 - val_loss: nan - val_acc: 0.1000
# Epoch 6/20
#  - 0s - loss: nan - acc: 0.1125 - val_loss: nan - val_acc: 0.1000
# Epoch 7/20
#  - 0s - loss: nan - acc: 0.1125 - val_loss: nan - val_acc: 0.1000
# Epoch 8/20
#  - 0s - loss: nan - acc: 0.1125 - val_loss: nan - val_acc: 0.1000
# Epoch 9/20
#  - 1s - loss: nan - acc: 0.1125 - val_loss: nan - val_acc: 0.1000
# Epoch 10/20
#  - 1s - loss: nan - acc: 0.1125 - val_loss: nan - val_acc: 0.1000
# Epoch 11/20
#  - 0s - loss: nan - acc: 0.1125 - val_loss: nan - val_acc: 0.1000
# Epoch 12/20
#  - 0s - loss: nan - acc: 0.1125 - val_loss: nan - val_acc: 0.1000
# Epoch 13/20
#  - 0s - loss: nan - acc: 0.1125 - val_loss: nan - val_acc: 0.1000
# Epoch 14/20
#  - 0s - loss: nan - acc: 0.1125 - val_loss: nan - val_acc: 0.1000
# Epoch 15/20
#  - 0s - loss: nan - acc: 0.1125 - val_loss: nan - val_acc: 0.1000
# Epoch 16/20
#  - 0s - loss: nan - acc: 0.1125 - val_loss: nan - val_acc: 0.1000
# Epoch 17/20
#  - 0s - loss: nan - acc: 0.1125 - val_loss: nan - val_acc: 0.1000
# Epoch 18/20
#  - 0s - loss: nan - acc: 0.1125 - val_loss: nan - val_acc: 0.1000
# Epoch 19/20
#  - 0s - loss: nan - acc: 0.1125 - val_loss: nan - val_acc: 0.1000
# Epoch 20/20
#  - 0s - loss: nan - acc: 0.1125 - val_loss: nan - val_acc: 0.1000

# %%
plt.plot(hist.history['loss'], color='b')
plt.plot(hist.history['val_loss'], color='r')
plt.show()

# %%
model.evaluate(x_test, y_test)
# Out:
# 20/20 [==============================] - 0s 1ms/step
# [nan, 0.10000000149011612]

# %%
import scipy.ndimage.filters as sp
y_hat=model.predict(x_train)
#y_hat=sp.gaussian_filter1d(model.predict(x_train),10)
np.shape(y_hat)
for i in range(100):
    plt.plot(y_train[i,:])
    plt.plot(y_hat[i,:],'.')
    plt.ylim((0,1))
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-104-8bc61afae264> in <module>
#       4 np.shape(y_hat)
#       5 for i in range(100):
# ----> 6     plt.plot(y_train[i,:])
#       7     plt.plot(y_hat[i,:],'.')
#       8     plt.ylim((0,1))
#
# IndexError: index 80 is out of bounds for axis 0 with size 80

# %%
for i in range(10):
    plt.plot(np.gradient(y_train[i,:])*100)
    plt.plot(np.gradient(y_hat[i,:])*100,'.')
    plt.ylim((-1,1))
    plt.show()

# %%
np.shape(y_test[:,:-1])
